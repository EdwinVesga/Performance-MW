# %%
# %matplotlib inline
# %run SSLTestScript

# %% [markdown]
# # ResponseTime Boxplot

# %%
graficarBox(pvP, ptP, pjP, pnP, "Spike")

# %% [markdown]
# # Active Threads vs timeStamp

# %%
plot_ActiveThreads(pvP,"Spike", "VertX")

# %%
plot_ActiveThreads(ptP,"Spike", "Tomcat")

# %%
plot_ActiveThreads(pjP,"Spike", "Jetty")

# %%
plot_ActiveThreads(pnP,"Spike", "NodeJS")

# %% [markdown]
# # ResponseTime vs timeStamp

# %%
plot_ElapsedTime(pvP,"Spike", "VertX")
# Out:
# /home/edwinvesga/Documentos/Performance-MW/SSLTestScript:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df1["timeStamp"] = df1["timeStamp"].map(lambda x: (x - min1)/1000)

# %%
plot_ElapsedTime(ptP,"Spike", "Tomcat")
# Out:
# /home/edwinvesga/Documentos/Performance-MW/SSLTestScript:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df1["timeStamp"] = df1["timeStamp"].map(lambda x: (x - min1)/1000)

# %%
plot_ElapsedTime(pjP,"Spike", "Jetty")
# Out:
# /home/edwinvesga/Documentos/Performance-MW/SSLTestScript:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df1["timeStamp"] = df1["timeStamp"].map(lambda x: (x - min1)/1000)

# %%
plot_ElapsedTime(pnP,"Spike", "NodeJS")
# Out:
# /home/edwinvesga/Documentos/Performance-MW/SSLTestScript:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df1["timeStamp"] = df1["timeStamp"].map(lambda x: (x - min1)/1000)

# %% [markdown]
# # % CPU vs timeStamp

# %%
plot_CPU(mpvP,mptP,mpjP,mpnP,"Spike")

# %% [markdown]
# # Memory vs timeStamp

# %%
plot_Memory(mpvP,mptP,mpjP,mpnP,"Spike")

# %% [markdown]
# # Reporte Resumen VertX

# %%
spvP
# Out:
#         Etiqueta  # Muestras  Media  Mediana  90% Line  95% Line  99% Line  \
# 0  Petición HTTP      178007   1198     1020      2364      2827      3823
# 1          Total      178007   1198     1020      2364      2827      3823
#
#    Mín    Máx % Error Rendimiento Kb/sec Desv. Estándar
# 0    2  19955   1,67%       456,6  164,9         989,90
# 1    2  19955   1,67%       456,6  164,9         989,90

# %% [markdown]
# # Reporte Resumen Tomcat

# %%
sptP
# Out:
#         Etiqueta  # Muestras  Media  Mediana  90% Line  95% Line  99% Line  \
# 0  Petición HTTP      223136   1063      603      2320      3090      5027
# 1          Total      223136   1063      603      2320      3090      5027
#
#    Mín    Máx % Error Rendimiento Kb/sec Desv. Estándar
# 0    2  67451   2,50%       572,3  278,1        2552,60
# 1    2  67451   2,50%       572,3  278,1        2552,60

# %% [markdown]
# # Reporte Resumen Jetty

# %%
spjP
# Out:
#         Etiqueta  # Muestras  Media  Mediana  90% Line  95% Line  99% Line  \
# 0  Petición HTTP      151701   1284     1267      2409      2700      3340
# 1          Total      151701   1284     1267      2409      2700      3340
#
#    Mín   Máx % Error Rendimiento Kb/sec Desv. Estándar
# 0    2  6127   2,10%       389,1  198,2         849,37
# 1    2  6127   2,10%       389,1  198,2         849,37

# %% [markdown]
# # Reporte Resumen NodeJS

# %%
spnP
# Out:
#         Etiqueta  # Muestras  Media  Mediana  90% Line  95% Line  99% Line  \
# 0  Petición HTTP      136650   1477      950      2706      3359      6405
# 1          Total      136650   1477      950      2706      3359      6405
#
#    Mín     Máx % Error Rendimiento Kb/sec Desv. Estándar
# 0    2  120382   2,11%       350,5  190,9        2950,10
# 1    2  120382   2,11%       350,5  190,9        2950,10
