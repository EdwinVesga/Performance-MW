# %%
# %matplotlib inline
# %run SSLTestScript
# Out:
# /home/viviana/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2681: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.compile if shell_futures else None)
# /home/viviana/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2681: DtypeWarning: Columns (3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.compile if shell_futures else None)

# %%
graficarHists(pvC, ptC, pjC, pnCL, "Carga")

# %%
graficarHists(pvCL, ptCL, pjCL, pnC, "Carga")

# %% [markdown]
# # Active Threads vs ElapsedTime

# %%
plot_ActiveThreads(pvC,"Carga", "VertX")

# %%
plot_ActiveThreads(ptC,"Carga", "Tomcat")

# %%
plot_ActiveThreads(pjC,"Carga", "Jetty")

# %%
plot_ActiveThreads(pnCL,"Carga", "NodeJS")

# %%
plot_ActiveThreads(pvCL,"Carga", "NodeJS")

# %%
plot_ActiveThreads(ptCL,"Carga", "NodeJS")

# %%
plot_ActiveThreads(pjCL,"Carga", "NodeJS")

# %%
plot_ActiveThreads(pnC,"Carga", "NodeJS")

# %% [markdown]
# # ResponseTime Boxplot

# %%
graficarBox(pvC, ptC, pjC, pnCL, "Carga")

# %%
graficarBox(pvCL, ptCL, pjCL, pnC, "Carga")

# %% [markdown]
# # ResponseTime vs ElapsedTime

# %%
plot_ElapsedTime(pvC,"Carga", "VertX")

# %%
plot_ElapsedTime(ptC,"Carga", "Tomcat")

# %%
plot_ElapsedTime(pjC,"Carga", "Jetty")

# %%
plot_ElapsedTime(pnCL,"Carga", "NodeJS")

# %% [markdown]
# # % CPU vs ElapsedTime

# %%
plot_CPU(mpvC,mptC,mpjC,mpnCL,"Carga")

# %%
plot_CPU(mpvCL,mptCL,mpjCL,mpnC,"Carga")

# %% [markdown]
# # Memory vs ElapsedTime

# %%
plot_Memory(mpvC,mptC,mpjC,mpnCL,"Carga")

# %%
plot_Memory(mpvCL,mptCL,mpjCL,mpnC,"Carga")

# %% [markdown]
# # Reporte Resumen VertX

# %%
spvC
# Out:
#         Etiqueta  # Muestras  Media  Mediana  90% Line  95% Line  99% Line  \
# 0  Petición HTTP      112907    940      738      2065      2500      3503
# 1          Total      112907    940      738      2065      2500      3503
#
#    Mín   Máx % Error Rendimiento Kb/sec Desv. Estándar
# 0    6  7283   0,00%       859,9  286,2         798,23
# 1    6  7283   0,00%       859,9  286,2         798,23

# %%
spvCL
# Out:
#         Etiqueta  # Muestras  Media  Mediana  90% Line  95% Line  99% Line  \
# 0  Petición HTTP      112628   1065      892      2240      2728      3794
# 1          Total      112628   1065      892      2240      2728      3794
#
#    Mín   Máx % Error Rendimiento Kb/sec Desv. Estándar
# 0    9  6692   0,00%       856,2  285,0         851,15
# 1    9  6692   0,00%       856,2  285,0         851,15

# %% [markdown]
# # Reporte Resumen Tomcat

# %%
sptC
# Out:
#         Etiqueta  # Muestras  Media  Mediana  90% Line  95% Line  99% Line  \
# 0  Petición HTTP      142151    738      454      1803      2355      3882
# 1          Total      142151    738      454      1803      2355      3882
#
#    Mín   Máx % Error Rendimiento Kb/sec Desv. Estándar
# 0    4  8045   0,00%      1089,4  486,2         820,76
# 1    4  8045   0,00%      1089,4  486,2         820,76

# %%
sptCL
# Out:
#         Etiqueta  # Muestras  Media  Mediana  90% Line  95% Line  99% Line  \
# 0  Petición HTTP      135807   1911      596      3269      9069     24058
# 1          Total      135807   1911      596      3269      9069     24058
#
#    Mín    Máx % Error Rendimiento Kb/sec Desv. Estándar
# 0    5  92540   0,00%       982,0  438,3        5149,74
# 1    5  92540   0,00%       982,0  438,3        5149,74

# %% [markdown]
# # Reporte Resumen Jetty

# %%
spjC
# Out:
#         Etiqueta  # Muestras  Media  Mediana  90% Line  95% Line  99% Line  \
# 0  Petición HTTP      101997   1043      858      2147      2463      3111
# 1          Total      101997   1043      858      2147      2463      3111
#
#    Mín   Máx % Error Rendimiento Kb/sec Desv. Estándar
# 0    7  5888   0,00%       769,9  366,8         771,01
# 1    7  5888   0,00%       769,9  366,8         771,01

# %%
spjCL
# Out:
#         Etiqueta  # Muestras  Media  Mediana  90% Line  95% Line  99% Line  \
# 0  Petición HTTP      101997   1043      858      2147      2463      3111
# 1          Total      101997   1043      858      2147      2463      3111
#
#    Mín   Máx % Error Rendimiento Kb/sec Desv. Estándar
# 0    7  5888   0,00%       769,9  366,8         771,01
# 1    7  5888   0,00%       769,9  366,8         771,01

# %% [markdown]
# # Reporte Resumen NodeJS

# %%
spnCL
# Out:
#         Etiqueta  # Muestras  Media  Mediana  90% Line  95% Line  99% Line  \
# 0  Petición HTTP       89567   1227      694      2336      2841      6069
# 1          Total       89567   1227      694      2336      2841      6069
#
#    Mín    Máx % Error Rendimiento Kb/sec Desv. Estándar
# 0    8  36756   0,00%       676,3  346,8        2116,14
# 1    8  36756   0,00%       676,3  346,8        2116,14

# %%
spnC
# Out:
#         Etiqueta  # Muestras  Media  Mediana  90% Line  95% Line  99% Line  \
# 0  Petición HTTP       89927   1185      787      2468      3092      4556
# 1          Total       89927   1185      787      2468      3092      4556
#
#    Mín    Máx % Error Rendimiento Kb/sec Desv. Estándar
# 0    9  21329   0,00%       680,9  349,1        1232,67
# 1    9  21329   0,00%       680,9  349,1        1232,67
