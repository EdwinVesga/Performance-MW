# %%
# %matplotlib inline
# %run ReadDatasets

# %% [markdown]
# # HeatMap -  ElapsedTime Media

# %%
heatmap()

# %% [markdown]
# # Throughput - 1000 HttpRequests

# %%
plot_bar(0)

# %% [markdown]
# # Throughput  JMeter - 1000 HttpRequest

# %%
plot_bar_Jmeter(0)

# %% [markdown]
# # Throughput - 2000 HttpRequests

# %%
plot_bar(1)

# %% [markdown]
# # Throughput  JMeter - 2000 HttpRequest

# %%
plot_bar_Jmeter(1)

# %% [markdown]
# # Throughput - 3000 HttpRequests

# %%
plot_bar(2)

# %% [markdown]
# # Throughput  JMeter - 3000 HttpRequest

# %%
plot_bar_Jmeter(2)

# %% [markdown]
# # DataFrames - Summary

# %% [markdown]
# ## Vert.X - Insertar

# %%
datos_insertar_vertx()
# Out:
#                                mean_1    mean_2     mean_3     mean_4  \
# APP_Periodo      INSERTAR
# Vertx_Periodo_6  1000_1      7.283000  7.609000   6.967000   6.565000
#                  1000_2      5.431000  6.681000   6.235000   6.784000
#                  1000_3      7.410000  9.807000   6.515000   7.229000
#                  2000_1      4.876000  6.633500   5.759500   5.450500
#                  2000_2      5.488500  4.634000   5.613000   7.894000
#                  2000_3    135.227500  8.698500   5.688000  22.912500
#                  3000_1      4.140667  8.216000   4.140333   4.940000
#                  3000_2      5.255667  4.492667   4.532333   8.088000
#                  3000_3      8.824333  7.802000  11.836333  45.879000
# Vertx_Periodo_8  1000_1      5.130000  5.344000   5.534000   4.672000
#                  1000_2      7.197000  6.243000   5.462000   5.695000
#                  1000_3      5.755000  5.696000   7.038000   6.279000
# ...

# %% [markdown]
# ## NodeJS - Insertar

# %%
datos_insertar_nodejs()
# Out:
#                               mean_1    mean_2    mean_3       mean_4  \
# APP_Periodo       INSERTAR
# NodeJS_Periodo_6  1000_1    2.683000  3.600000  3.409000     2.995000
#                   1000_2    3.225000  3.672000  3.234000     5.155000
#                   1000_3    5.564000  3.547000  3.719000     3.852000
#                   2000_1    3.416500  3.160500  3.685500     2.672000
#                   2000_2    4.364500  2.469500  3.590000     2.745000
#                   2000_3    3.335000  4.211000  4.871500     3.837000
#                   3000_1    4.092000  7.700667  3.678333     3.880667
#                   3000_2    2.804333  4.479333  2.775000     6.324000
#                   3000_3    3.758667  3.972667  5.110000  3236.074333
# NodeJS_Periodo_8  1000_1    2.435000  2.599000  2.857000     2.397000
#                   1000_2    2.629000  2.768000  3.923000     2.682000
#                   1000_3    3.201000  2.913000  2.897000     3.043000
# ...

# %% [markdown]
# ## Tomcat - Insertar

# %%
datos_insertar_tomcat()
# Out:
#                                mean_1     mean_2     mean_3     mean_4  \
# APP_Periodo       INSERTAR
# Tomcat_Periodo_6  1000_1     8.318000   6.683000   5.989000   5.788000
#                   1000_2    16.882000  15.014000  14.403000  13.124000
#                   1000_3    27.173000  27.981000  27.614000  33.578000
#                   2000_1     5.026500   5.318000   6.065500   5.676000
#                   2000_2    14.291000  17.818000  14.406500  16.765500
#                   2000_3    28.945000  29.562500  30.196500  37.758500
#                   3000_1     6.235667   7.696000   6.190000   6.511667
#                   3000_2    15.326000  15.202000  16.737667  22.103333
#                   3000_3    32.699333  35.846667  92.965333  53.653333
# Tomcat_Periodo_8  1000_1     5.226000   6.485000   5.767000   6.281000
#                   1000_2    11.182000  12.207000  11.023000  20.786000
#                   1000_3    31.558000  28.676000  28.667000  28.323000
# ...

# %% [markdown]
# ## Jetty - Insertar

# %%
datos_insertar_jetty()
# Out:
#                                  mean_1        mean_2        mean_3  \
# APP_Periodo      INSERTAR
# Jetty_Periodo_6  1000_1       14.177000     12.892000     14.035000
#                  1000_2      178.479000    215.704000    188.926000
#                  1000_3     3643.229000   3493.490000   3775.815000
#                  2000_1       13.801000     16.918000     14.851500
#                  2000_2     3125.471000   2898.841000   3208.093000
#                  2000_3     9339.494000   9199.848000   9315.490000
#                  3000_1      131.442333    161.270333    116.494667
#                  3000_2     5154.346000   5425.958667   5619.493667
#                  3000_3    14705.370667  14250.778333  13998.039667
# Jetty_Periodo_8  1000_1       53.466000     11.987000     64.691000
#                  1000_2       97.179000    103.363000     40.157000
#                  1000_3     1589.875000   2342.601000   2512.437000
# ...

# %% [markdown]
# ## Vert.X - Consulta

# %%
datos_consulta_vertx()
# Out:
#                              mean_1    mean_2    mean_3    mean_4      std_1  \
# APP_Periodo      CONSULTA
# Vertx_Periodo_6  1000_1    4.939000  5.522000  3.873000  3.564000  18.332847
#                  1000_2    5.132000  4.983000  5.150000  5.079000  12.619215
#                  1000_3    7.320000  7.004000  7.443000  6.720000  14.309144
#                  2000_1    3.270500  3.810500  3.736000  2.721000  12.436050
#                  2000_2    5.464500  4.354000  6.593500  4.885500  15.841614
#                  2000_3    6.994000  7.293500  6.512000  6.609500  12.707634
#                  3000_1    3.713667  2.511000  2.622333  3.445333  16.034806
#                  3000_2    5.317667  5.082667  4.427333  4.893667  16.326300
#                  3000_3    6.839667  6.965667  6.208667  6.882333  11.052992
# Vertx_Periodo_8  1000_1    3.078000  2.869000  2.860000  3.587000  10.869403
#                  1000_2    4.937000  4.701000  4.496000  4.767000  12.060640
# ...

# %% [markdown]
# ## NodeJS - Consulta

# %%
datos_consulta_nodejs()
# Out:
#                               mean_1    mean_2     mean_3    mean_4  \
# APP_Periodo       CONSULTA
# NodeJS_Periodo_6  1000_1    4.389000  3.104000   3.528000  3.613000
#                   1000_2    7.677000  5.335000   5.848000  5.363000
#                   1000_3    7.180000  6.445000   6.975000  6.706000
#                   2000_1    3.097500  4.613500   4.526000  3.700500
#                   2000_2    6.628500  7.474500   5.885500  5.442500
#                   2000_3    6.995000  7.548000   7.210000  7.077500
#                   3000_1    3.588000  3.255333   3.780333  3.901000
#                   3000_2    4.171333  5.970000   5.336333  4.542333
#                   3000_3    9.220667  9.078000  10.068000  9.898333
# NodeJS_Periodo_8  1000_1    3.264000  3.727000   2.768000  2.898000
#                   1000_2    4.610000  4.476000   4.472000  4.174000
#                   1000_3    6.277000  6.579000   6.017000  6.708000
# ...

# %% [markdown]
# ## Tomcat - Consulta

# %%
datos_consulta_tomcat()
# Out:
#                               mean_1    mean_2    mean_3    mean_4      std_1  \
# APP_Periodo       CONSULTA
# Tomcat_Periodo_6  1000_1    2.815000  3.985000  2.939000  3.357000  10.859410
#                   1000_2    4.620000  4.060000  5.069000  3.691000  14.096581
#                   1000_3    6.283000  5.812000  4.974000  5.589000  15.434536
#                   2000_1    3.228000  3.854500  2.946000  2.123000  13.954104
#                   2000_2    5.897500  4.114500  5.605500  3.584000  21.378026
#                   2000_3    6.238000  6.189000  5.520500  5.528000  14.877243
#                   3000_1    2.215333  3.140000  2.751333  5.540333   8.323799
#                   3000_2    5.844667  5.767000  5.597667  3.736667  19.932801
#                   3000_3    6.429333  7.060000  5.625333  5.528000  23.135247
# Tomcat_Periodo_8  1000_1    2.023000  2.409000  2.685000  2.180000   7.227065
#                   1000_2    3.420000  3.284000  3.374000  3.379000   9.005643
# ...

# %% [markdown]
# ## Jetty - Consulta

# %%
datos_consulta_jetty()
# Out:
#                               mean_1     mean_2     mean_3     mean_4  \
# APP_Periodo      CONSULTA
# Jetty_Periodo_6  1000_1     7.949000   4.639000   4.912000   5.175000
#                  1000_2     6.991000   6.378000   6.560000   6.075000
#                  1000_3     7.500000  12.555000  14.697000   7.867000
#                  2000_1    20.438500   5.227500   6.268000   9.269000
#                  2000_2     6.053500  30.295500   6.501500   5.940500
#                  2000_3    22.718500   7.530500  33.479500  43.858500
#                  3000_1    22.161000  11.182667   4.594333   4.775667
#                  3000_2    32.241333  37.010333  41.938667  54.990000
#                  3000_3    25.066000  30.896000  42.836000   7.852333
# Jetty_Periodo_8  1000_1     3.749000   4.152000   4.303000   4.177000
#                  1000_2     5.408000   5.031000  11.256000   5.229000
#                  1000_3     6.690000  13.490000   6.522000   8.983000
# ...

# %% [markdown]
# ## Vert.X - Contar Primos

# %%
datos_contarprimos_vertx()
# Out:
#                                   mean_1    mean_2    mean_3    mean_4  \
# APP_Periodo      CONTAR_PRIMOS
# Vertx_Periodo_6  1000_1         4.220000  2.773000  3.015000  3.748000
#                  1000_2         3.905000  3.324000  3.422000  3.402000
#                  1000_3         3.937000  3.975000  4.582000  4.095000
#                  2000_1         3.074000  3.648000  2.773500  3.988500
#                  2000_2         3.835500  3.238500  2.943500  4.006000
#                  2000_3         4.453500  3.774000  3.422500  4.314000
#                  3000_1         2.758333  2.247667  5.241000  2.802667
#                  3000_2         4.624333  4.095667  3.354333  4.313000
#                  3000_3         5.368667  3.883333  3.140000  3.708333
# Vertx_Periodo_8  1000_1         3.191000  2.618000  2.221000  2.479000
#                  1000_2         2.696000  3.111000  3.014000  2.440000
#                  1000_3         3.932000  4.035000  3.489000  3.290000
# ...

# %% [markdown]
# ## NodeJS - Contar Primos

# %%
datos_contarprimos_nodejs()
# Out:
#                                    mean_1    mean_2    mean_3    mean_4  \
# APP_Periodo       CONTAR_PRIMOS
# NodeJS_Periodo_6  1000_1         3.360000  3.753000  3.125000  2.632000
#                   1000_2         3.395000  3.472000  4.383000  3.835000
#                   1000_3         6.558000  5.458000  4.996000  4.597000
#                   2000_1         2.508000  3.242500  2.568000  3.231500
#                   2000_2         5.083000  4.078500  3.988500  7.080000
#                   2000_3         6.066000  5.316500  4.251500  4.787500
#                   3000_1         2.138000  3.233333  3.948667  3.033667
#                   3000_2         6.078333  4.768333  4.257333  5.187000
#                   3000_3         4.820333  5.518333  6.844667  5.377333
# NodeJS_Periodo_8  1000_1         2.736000  2.893000  2.450000  2.509000
#                   1000_2         3.319000  2.944000  3.063000  3.308000
#                   1000_3         5.351000  4.150000  4.706000  4.497000
# ...

# %% [markdown]
# ## Tomcat - Contar Primos

# %%
datos_contarprimos_tomcat()
# Out:
#                                    mean_1    mean_2    mean_3    mean_4  \
# APP_Periodo       CONTAR_PRIMOS
# Tomcat_Periodo_6  1000_1         3.136000  2.172000  2.697000  2.299000
#                   1000_2         3.012000  3.935000  2.787000  2.958000
#                   1000_3         3.338000  4.052000  6.947000  3.981000
#                   2000_1         2.888500  3.150000  1.829500  2.737000
#                   2000_2         4.187000  5.226500  3.357000  2.678000
#                   2000_3         3.652500  3.764500  4.430500  8.046000
#                   3000_1         1.905667  2.165667  2.032000  2.298000
#                   3000_2         2.200333  2.571667  4.216000  4.288667
#                   3000_3         3.913333  4.731000  4.171667  3.191000
# Tomcat_Periodo_8  1000_1         1.928000  1.739000  1.578000  2.188000
#                   1000_2         2.534000  2.179000  2.378000  2.442000
#                   1000_3         3.355000  3.319000  3.060000  3.491000
# ...

# %% [markdown]
# ## Jetty - Contar Primos

# %%
datos_contarprimos_jetty()
# Out:
#                                   mean_1    mean_2    mean_3    mean_4  \
# APP_Periodo      CONTAR_PRIMOS
# Jetty_Periodo_6  1000_1         3.828000  2.010000  3.058000  2.513000
#                  1000_2         7.446000  3.111000  4.500000  3.224000
#                  1000_3         3.704000  4.630000  3.786000  6.670000
#                  2000_1         3.816500  2.406000  2.911500  3.412000
#                  2000_2         3.236500  2.544000  3.219000  3.047000
#                  2000_3         4.074000  4.048500  5.793500  4.178500
#                  3000_1         2.535000  3.018000  2.410667  3.569667
#                  3000_2         3.094333  4.381667  3.458000  2.882333
#                  3000_3         4.616667  3.458333  4.970000  5.725667
# Jetty_Periodo_8  1000_1         1.835000  1.878000  1.670000  2.075000
#                  1000_2         2.468000  2.648000  2.666000  2.506000
#                  1000_3         2.845000  3.593000  3.459000  2.852000
# ...
