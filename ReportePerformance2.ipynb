# %%
# %matplotlib inline
# %run ReadDatasets

# %% [markdown]
# # Performance Monitoring - CPU & Memory vs timeStamp

# %% [markdown]
# ## Consultas

# %%
plot_PerfMon_Consultas(0,0)

# %%
plot_PerfMon_Consultas(0,1)

# %%
plot_PerfMon_Consultas(0,2)

# %%
plot_PerfMon_Consultas(1,0)

# %%
plot_PerfMon_Consultas(1,1)

# %%
plot_PerfMon_Consultas(1,2)

# %%
plot_PerfMon_Consultas(2,0)

# %%
plot_PerfMon_Consultas(2,1)

# %%
plot_PerfMon_Consultas(2,2)

# %% [markdown]
# ## Insertar

# %%
plot_PerfMon_Insertar(0,0)

# %%
plot_PerfMon_Insertar(0,1)

# %%
plot_PerfMon_Insertar(0,2)

# %%
plot_PerfMon_Insertar(1,0)

# %%
plot_PerfMon_Insertar(1,1)

# %%
plot_PerfMon_Insertar(1,2)

# %%
plot_PerfMon_Insertar(2,0)

# %%
plot_PerfMon_Insertar(2,1)

# %%
plot_PerfMon_Insertar(2,2)

# %% [markdown]
# ## ContarPrimos

# %%
plot_PerfMon_ContarPrimos(0,0)

# %%
plot_PerfMon_ContarPrimos(0,1)

# %%
plot_PerfMon_ContarPrimos(0,2)

# %%
plot_PerfMon_ContarPrimos(1,0)

# %%
plot_PerfMon_ContarPrimos(1,1)

# %%
plot_PerfMon_ContarPrimos(1,2)

# %%
plot_PerfMon_ContarPrimos(2,0)

# %%
plot_PerfMon_ContarPrimos(2,1)

# %%
plot_PerfMon_ContarPrimos(2,2)

# %% [markdown]
# # ResponseTime vs timeStamp

# %% [markdown]
# ## Insertar

# %%
plot_ResponseTime_Insertar(0,0)

# %%
plot_ResponseTime_Insertar(2,2)

# %% [markdown]
# ## Consulta

# %%
plot_ResponseTime_Consulta(0,0)

# %%
plot_ResponseTime_Consulta(2,2)

# %% [markdown]
# ## ContarPrimos

# %%
plot_ResponseTime_ContarPrimos(0,0)

# %%
plot_ResponseTime_ContarPrimos(2,2)
